# %% [markdown]
# # Data Exploration

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Mushroom Classification Dataset

# %% [markdown]
# To access this database, you can use this [link](https://www.kaggle.com/datasets/uciml/mushroom-classification).

# %%
df = pd.read_csv("DATA/mushrooms.csv")

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %% [markdown]
# As seen from above, our dataset has 23 columns. Each column has a different feature of the mushrooms which are the column names of the dataset.

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# In the EDA step, I will visualize each feature by its class distribution. The "class" refers that the information of this mushroom is edible or poisonous.

# %% [markdown]
# ### Mushroom class

# %%
plt.figure(figsize=(6, 6), dpi=100)
plt.title("Distribution of the Mushrooms by their Classes")
plt.pie([df["class"].value_counts()[0], df["class"].value_counts()[1]], labels=["Edible", "Poisonous"], autopct='%1.1f%%', colors=["seagreen", "indianred"], wedgeprops = {"edgecolor" : "black", "linewidth": 2, "antialiased": True})
plt.legend()
plt.show()

# %% [markdown]
# As seen from the figure above, the red part represents that the percentage of the poisonous mushrooms in the dataset. The green part represents that the percentage of edible mushrooms. Since the percentages of these classes are pretty close to each other, we don't really need to balance the classes. From now on, I will represent the red color for the poisonous class and green for the edible class of the mushrooms.

# %% [markdown]
# ### Cap Shapes

# %% [markdown]
# ![mushroom-cap-shapes](images/mushroom-cap-shapes.webp)

# %%
plt.figure(figsize=(12, 6), dpi=200)
plot = sns.countplot(x="cap-shape", data=df, hue="class", palette=["indianred", "seagreen"], order=df["cap-shape"].value_counts().index, edgecolor=(0, 0, 0), linewidth=2)
plot.set_xticklabels(["Convex", "Flat", "Knobbed", "Bell", "Sunken", "Conical"])
plt.legend(["Poisonous", "Edible"], loc="upper right")
plt.ylabel("Number of the Mushrooms", fontsize=12)
plt.xlabel("Types of the Cap Shapes of the Mushrooms", fontsize=12)
plt.title("Distribution of the Mushrooms by their Classes and Cap Shapes", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Cap Shapes')

# %% [markdown]
# According to this graph, the Convex Cap Shape is the most frequent. The Edible and Poisonous class mushrooms are pretty close to each other for the Convex and the Flat type. In contrast, for the following types which are Kobbed and Bell, the class types are pretty imbalanced distributed. The Sunken type is completely edible. The Conical type is completely poisonous.

# %% [markdown]
# ### Cap Surfaces

# %% [markdown]
# ![mushroom-cap-shapes](images/mushroom-cap-surfaces.jpeg)

# %%
plt.figure(figsize=(12, 6), dpi=200)
plot = sns.countplot(x="cap-surface", data=df, hue="class", palette=["indianred", "seagreen"], order=df["cap-surface"].value_counts().index, edgecolor=(0, 0, 0), linewidth=2)
plot.set_xticklabels(["Scaly", "Smooth", "Fibrous", "Grooves"])
plt.legend(["Poisonous", "Edible"], loc="upper right")
plt.ylabel("Number of the Mushrooms", fontsize=12)
plt.xlabel("Types of the Cap Surfaces of the Mushrooms", fontsize=12)
plt.title("Distribution of the Mushrooms by their Classes and Cap Surfaces", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Cap Surfaces')

# %% [markdown]
# As seen from the figure, the Scaly and Smooth types are high probability poisonous. In contrast, the Fibrous type is mostly edible.

# %% [markdown]
# ### Cap Color

# %%
plt.figure(figsize=(12, 6), dpi=200)
plot = sns.countplot(x="cap-color", data=df, hue="class", palette=["indianred", "seagreen"], order=df["cap-color"].value_counts().index, edgecolor=(0, 0, 0), linewidth=2)
plot.set_xticklabels(["Brown", "Gray", "Red", "Yellow", "White", "Buff", "Pink", "Cinnamon", "Purple", "Green"])
plt.legend(["Poisonous", "Edible"], loc="upper right")
plt.ylabel("Number of the Mushrooms", fontsize=12)
plt.xlabel("The Cap Colors of the Mushrooms", fontsize=12)
plt.title("Distribution of the Mushrooms by their Classes and Cap Colors", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Cap Colors')

# %% [markdown]
# According to this graph, the Edible and Poisonous class mushrooms are pretty close to each other for Brown, Gray, and Red cap colors. The White cap-colored mushrooms are highly edible. Purple and Green cape-colored mushrooms have no poisonous class.

# %% [markdown]
# ### Bruises

# %%
plt.figure(figsize=(12, 6), dpi=200)
plot = sns.countplot(x="bruises", data=df, hue="class", palette=["indianred", "seagreen"], order=df["bruises"].value_counts().index, edgecolor=(0, 0, 0), linewidth=2)
plot.set_xticklabels(["Mushrooms without Bruises", "Mushrooms with Bruises"])
plt.legend(["Poisonous", "Edible"], loc="upper right")
plt.ylabel("Number of the Mushrooms", fontsize=12)
plt.xlabel("Mushrooms by having Bruises", fontsize=12)
plt.title("Distribution of the Mushrooms by their Classes and Bruises", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Bruises')

# %% [markdown]
# Mushrooms without Bruises are high frequently poisonous. In contrast, the Mushrooms with the Bruises are highly edible.

# %% [markdown]
# ### Odor

# %%
plt.figure(figsize=(12, 6), dpi=200)
plot = sns.countplot(x="odor", data=df, hue="class", palette=["indianred", "seagreen"], order=df["odor"].value_counts().index, edgecolor=(0, 0, 0), linewidth=2)
plot.set_xticklabels(["No Odor", "Foul", "Fishy", "Spicy", "Anise", "Almond", "Pungent", "Creosote", "Musty"])
plt.legend(["Poisonous", "Edible"], loc="upper right")
plt.ylabel("Number of the Mushrooms", fontsize=12)
plt.xlabel("Odor of the Mushrooms", fontsize=12)
plt.title("Distribution of the Mushrooms by their Classes and Odor", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Odor')

# %% [markdown]
# According to the graph above, mushrooms with no odor are highly safe for humans. But the mushrooms with the Foul, Fishy, and Spicy odor are high frequently poisonous. The mushrooms with the Anise and Almond odor have no poisonous class.

# %% [markdown]
# ### Gill Attachment

# %%
plt.figure(figsize=(12, 6), dpi=200)
plot = sns.countplot(x="gill-attachment", data=df, hue="class", palette=["indianred", "seagreen"], order=df["gill-attachment"].value_counts().index, edgecolor=(0, 0, 0), linewidth=2)
plot.set_xticklabels(["Free", "Attached"])
plt.legend(["Poisonous", "Edible"], loc="upper right")
plt.ylabel("Number of the Mushrooms", fontsize=12)
plt.xlabel("Types of the Gill Attachments", fontsize=12)
plt.title("Distribution of the Mushrooms by their Classes and Gill Attachments", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Gill Attachments')

# %% [markdown]
#  The dataset has high frequently Free type gill attachments. According to this graph, the Free type gill attachments are approximately equally distributed. In contrast, the Attached type gill attachments are most frequently edible.

# %% [markdown]
# ### Gill Spacing

# %% [markdown]
# ![mushroom-cap-shapes](images/mushroom-gill-spacing.png)

# %%
plt.figure(figsize=(12, 6), dpi=200)
plot = sns.countplot(x="gill-spacing", data=df, hue="class", palette=["indianred", "seagreen"], order=df["gill-spacing"].value_counts().index, edgecolor=(0, 0, 0), linewidth=2)
plot.set_xticklabels(["Close", "Crowded"])
plt.legend(["Poisonous", "Edible"], loc="upper right")
plt.ylabel("Number of the Mushrooms", fontsize=12)
plt.xlabel("Types of the Gill Spacing", fontsize=12)
plt.title("Distribution of the Mushrooms by their Classes and Gill Spacing", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Gill Spacing')

# %% [markdown]
# The Crowded type gill spacing is high frequently edible. In contrast, we cannot say the same thing for the Close-type gill spacing mushrooms. Their class distribution by gill spacing is pretty close to each other.

# %% [markdown]
# ### Gil Color

# %%
plt.figure(figsize=(12, 6), dpi=200)
plot = sns.countplot(x="gill-color", data=df, hue="class", palette=["indianred", "seagreen"], order=df["gill-color"].value_counts().index, edgecolor=(0, 0, 0), linewidth=2)
plot.set_xticklabels(["Buff", "Pink", "White", "Brown", "Gray", "Chocolate", "Purple", "Black", "Red", "Yellow", "Orange", "Green"])
plt.legend(["Poisonous", "Edible"], loc="upper right")
plt.ylabel("Number of the Mushrooms", fontsize=12)
plt.xlabel("The Gill Colors of the Mushrooms", fontsize=12)
plt.title("Distribution of the Mushrooms by their Classes and Gill Colors", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Gill Colors')

# %% [markdown]
# The Buff-colored gills are highly poisonous. In contrast, the White, Brown, Purple, Black, and Red gill colors are high frequently edible.

# %% [markdown]
# ### Stalk Shape

# %% [markdown]
# ![mushroom-cap-shapes](images/mushroom-stalk-shapes.jpeg)

# %%
plt.figure(figsize=(12, 6), dpi=200)
plot = sns.countplot(x="stalk-shape", data=df, hue="class", palette=["indianred", "seagreen"], order=df["stalk-shape"].value_counts().index, edgecolor=(0, 0, 0), linewidth=2)
plot.set_xticklabels(["Tapering", "Enlarging"])
plt.legend(["Poisonous", "Edible"], loc="upper right")
plt.ylabel("Number of the Mushrooms", fontsize=12)
plt.xlabel("Types of the Stalk Shapes", fontsize=12)
plt.title("Distribution of the Mushrooms by their Classes and Stalk Shapes", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Stalk Shapes')

# %% [markdown]
# ### Stalk Root

# %% [markdown]
# ![mushroom-cap-shapes](images/mushroom-stalk-roots.jpeg)

# %%
plt.figure(figsize=(12, 6), dpi=200)
plot = sns.countplot(x="stalk-root", data=df, hue="class", palette=["indianred", "seagreen"], order=df["stalk-root"].value_counts().index, edgecolor=(0, 0, 0), linewidth=2)
plot.set_xticklabels(["Bulbous", "N/A", "Equal", "Club", "Rooted"])
plt.legend(["Poisonous", "Edible"], loc="upper right")
plt.ylabel("Number of the Mushrooms", fontsize=12)
plt.xlabel("Types of the Roots", fontsize=12)
plt.title("Distribution of the Mushrooms by their Classes and Roots", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Roots')

# %% [markdown]
# The stalk-root feature has missing values. The Equal, Club, and Rooted type stalk roots are highly edible.

# %% [markdown]
# ### Veil types

# %%
plt.figure(figsize=(12, 6), dpi=200)
plot = sns.countplot(x="veil-type", data=df, hue="class", palette=["indianred", "seagreen"], order=df["veil-type"].value_counts().index, edgecolor=(0, 0, 0), linewidth=2)
plot.set_xticklabels(["Partial"])
plt.legend(["Poisonous", "Edible"], loc="upper right")
plt.ylabel("Number of the Mushrooms", fontsize=12)
plt.xlabel("Types of the Veils", fontsize=12)
plt.title("Distribution of the Mushrooms by their Classes and Veil Types", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Veil Types')

# %% [markdown]
# In this dataset, we have only Partial type Veils. As you can see, most of them are edible but the number of the poisonous class mushrooms are pretty close to the edible class of mushrooms.

# %% [markdown]
# ### Veil Colors

# %%
plt.figure(figsize=(12, 6), dpi=200)
plot = sns.countplot(x="veil-color", data=df, hue="class", palette=["indianred", "seagreen"], order=df["veil-color"].value_counts().index, edgecolor=(0, 0, 0), linewidth=2)
plot.set_xticklabels(["White", "Brown", "Orange", "Yellow"])
plt.legend(["Poisonous", "Edible"], loc="upper right")
plt.ylabel("Number of the Mushrooms", fontsize=12)
plt.xlabel("Veil Colors", fontsize=12)
plt.title("Distribution of the Mushrooms by their Classes and Veil Colors", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Veil Colors')

# %% [markdown]
# Most of the mushrooms have White colors. The class distribution of the White-colored Veils is approximately equal. The Brown, Orange, and Yellow Veil-colored mushrooms have no poisonous class.

# %% [markdown]
# ### Number of the Rings

# %%
plt.figure(figsize=(12, 6), dpi=200)
plot = sns.countplot(x="ring-number", data=df, hue="class", palette=["indianred", "seagreen"], order=df["ring-number"].value_counts().index, edgecolor=(0, 0, 0), linewidth=2)
plot.set_xticklabels(["One", "Two", "None",])
plt.legend(["Poisonous", "Edible"], loc="upper right")
plt.ylabel("Number of the Mushrooms", fontsize=12)
plt.xlabel("Number of the Rings", fontsize=12)
plt.title("Distribution of the Mushrooms by their Classes and Number of the Rings", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Number of the Rings')

# %% [markdown]
# ### Ring Types

# %% [markdown]
# ![mushroom-cap-shapes](images/mushroom-ring-types.jpeg)

# %%
plt.figure(figsize=(12, 6), dpi=200)
plot = sns.countplot(x="ring-type", data=df, hue="class", palette=["indianred", "seagreen"], order=df["ring-type"].value_counts().index, edgecolor=(0, 0, 0), linewidth=2)
plot.set_xticklabels(["Pendant", "Evanescent", "Large", "Flaring", "None"])
plt.legend(["Poisonous", "Edible"], loc="upper right")
plt.ylabel("Number of the Mushrooms", fontsize=12)
plt.xlabel("Ring Types", fontsize=12)
plt.title("Distribution of the Mushrooms by their Classes and Ring Types", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Ring Types')

# %% [markdown]
# As seen from the graph, the mushrooms with the Pendant type are high frequently edible. In contrast, the mushrooms with the Large type have only the poisonous class.

# %% [markdown]
# ### Spore Print Colors

# %%
plt.figure(figsize=(12, 6), dpi=200)
plot = sns.countplot(x="spore-print-color", data=df, hue="class", palette=["indianred", "seagreen"], order=df["spore-print-color"].value_counts().index, edgecolor=(0, 0, 0), linewidth=2)
plot.set_xticklabels(["White", "Brown", "Black", "Chocolate", "Green", "Orange", "Yellow", "Buff", "Purple"])
plt.legend(["Poisonous", "Edible"], loc="upper right")
plt.ylabel("Number of the Mushrooms", fontsize=12)
plt.xlabel("Spore Print Colors", fontsize=12)
plt.title("Distribution of the Mushrooms by their Classes and Spore Print Colors", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Spore Print Colors')

# %% [markdown]
# As seen from the figure, the White and Chocolate spore print colored mushrooms are high frequently poisonous. In contrast, the mushrooms with the Brown and Black spore print colors are high frequently edible.

# %% [markdown]
# ### Populations

# %%
plt.figure(figsize=(12, 6), dpi=200)
plot = sns.countplot(x="population", data=df, hue="class", palette=["indianred", "seagreen"], order=df["population"].value_counts().index, edgecolor=(0, 0, 0), linewidth=2)
plot.set_xticklabels(["Several", "Solitary", "Scattered", "Numerous", "Abundant", "Clustered"])
plt.legend(["Poisonous", "Edible"], loc="upper right")
plt.ylabel("Number of the Mushrooms", fontsize=12)
plt.xlabel("Populations", fontsize=12)
plt.title("Distribution of the Mushrooms by their Classes and Populations", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Populations')

# %% [markdown]
# According to the graph above, the mushrooms populated as Several types are highly poisonous. In contrast, the mushrooms with Numerous, Abundant, and Clustered populations are pretty edible.

# %% [markdown]
# ### Habitats

# %%
plt.figure(figsize=(12, 6), dpi=200)
plot = sns.countplot(x="habitat", data=df, hue="class", palette=["indianred", "seagreen"], order=df["habitat"].value_counts().index, edgecolor=(0, 0, 0), linewidth=2)
plot.set_xticklabels(["Woods", "Grasses", "Paths", "Leaves", "Urban", "Meadows", "Waste"])
plt.legend(["Poisonous", "Edible"], loc="upper right")
plt.ylabel("Number of the Mushrooms", fontsize=12)
plt.xlabel("Habitats", fontsize=12)
plt.title("Distribution of the Mushrooms by their Classes and Habitats", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Habitats')
